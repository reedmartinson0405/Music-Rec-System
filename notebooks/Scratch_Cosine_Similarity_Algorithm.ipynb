# %% [markdown]
# # Cosine Similarity Algorithm

# %% [markdown]
# ## Business Understanding
#
# Cosine Similarity is an algorithm used to calculate how similar variables are to each other using metrics that describe each variable. What I hope to accomplish with this algorithm is to plug a song in and have the algorithm output 20 songs that are similar to the song plugged in. This will make it easy for users to discover new music and a fast way to create playlists!

# %%
import pandas as pd 
import numpy as np 
from numpy import dot 
import operator
from sklearn.metrics.pairwise import cosine_similarity 
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer 
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_validate

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# https://www.datasciencelearner.com/sklearn-cosine-similarity-implementation/

# %%
df = pd.read_csv('../data/final_df.csv', index_col=0)

# %%
df
# Out:
#                       track_id         track_name  track_popularity  \
# 0       35iwgR4jXetI318WEWsa1Q              Carve                 6
# 1       0PH9AACae1f957JAavhOl2           Lazy Boi                 0
# 2       2SiNuAZ6jIU9xhClRKXcST             Sketch                 0
# 3       4vV7uBcF2AnjNTOejBS5oL            L'enfer                 0
# 4       598LlBn6jpEpVbLjmZPsYV           Graphite                 0
# ...                        ...                ...               ...
# 470033  0MmaEacabpK8Yp3Mdeo5uY                下雨天                50
# 470034  1dKxf4Ht2SsKLyXfSDJAgy   The Cutest Puppy                67
# 470035  0SjsIzJkZfDU7wlcdklEFR  John Brown's Song                66
# 470036  5rgu12WBIHQtvej2MdHSH0                云与海                50
# 470037  0NuWgxEp51CutD2pJoF4OM              blind                72
#
#         duration_ms  explicit release_date  danceability   energy  key  \
# 0            126903         0   1922-02-22         0.645  0.44500    0
# 1            157333         0   1922-02-22         0.298  0.46000    1
# 2             87040         0   1922-02-22         0.634  0.00399    5
# 3             40000         0   1922-02-22         0.657  0.32500   10
# 4            104400         0   1922-02-22         0.644  0.68400    7
# ...             ...       ...          ...           ...      ...  ...
# 470033       265846         0   2020-02-25         0.528  0.67300    4
# 470034        82500         0   2020-10-30         0.609  0.01720    8
# 470035       185250         0   2020-03-20         0.562  0.03310    1
# 470036       258267         0   2020-09-26         0.560  0.51800    0
# 470037       153293         0   2020-10-21         0.765  0.66300    0
#
#         loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -13.338     1       0.4510         0.674          0.744000    0.1510
# 1        -18.645     1       0.4530         0.521          0.856000    0.4360
# 2        -29.973     0       0.0377         0.926          0.919000    0.1050
# 3        -14.319     0       0.2540         0.199          0.856000    0.0931
# 4         -8.247     1       0.1990         0.144          0.802000    0.0847
# ...          ...   ...          ...           ...               ...       ...
# 470033    -3.639     1       0.0314         0.143          0.000000    0.0989
# 470034   -28.573     1       0.1180         0.996          0.973000    0.1080
# 470035   -25.551     1       0.1030         0.996          0.961000    0.1110
# 470036    -7.471     0       0.0292         0.785          0.000000    0.0648
# 470037    -5.223     1       0.0652         0.141          0.000297    0.0924
#
#         valence    tempo  time_signature               artist_id  followers  \
# 0         0.127  104.851               3  45tIt06XoI0Iio4LBEVpls       91.0
# 1         0.402   87.921               4  45tIt06XoI0Iio4LBEVpls       91.0
# 2         0.396   79.895               4  45tIt06XoI0Iio4LBEVpls       91.0
# 3         0.105   81.944               5  45tIt06XoI0Iio4LBEVpls       91.0
# 4         0.138  100.031               4  45tIt06XoI0Iio4LBEVpls       91.0
# ...         ...      ...             ...                     ...        ...
# 470033    0.297  130.066               4  5VGgFE9nPgMfEnYiPT5J2B      929.0
# 470034    0.890   68.619               4  7vgGpuiXdNlCmc994PlMlz       23.0
# 470035    0.386   63.696               3  4MxqhahGRT4BPz1PilXGeu       91.0
# 470036    0.211  131.896               4  1QLBXKM5GCpyQQSVMNZqrZ      896.0
# 470037    0.686  150.091               4  1dy5WNgIKQU6ezkpZs4y8z   245944.0
#
#                                                    genres     artist_name  \
# 0                                                     NaN             Uli
# 1                                                     NaN             Uli
# 2                                                     NaN             Uli
# 3                                                     NaN             Uli
# 4                                                     NaN             Uli
# ...                                                   ...             ...
# 470033                                  chinese viral pop              芝麻
# 470034                               instrumental lullaby  Laureen Conrad
# 470035                               instrumental lullaby  Gregory Oberle
# 470036                                  chinese viral pop         阿YueYue
# 470037  alt z, alternative r&b, bedroom pop, indie caf...      ROLE MODEL
#
#         artist_popularity
# 0                       4
# 1                       4
# 2                       4
# 3                       4
# 4                       4
# ...                   ...
# 470033                 36
# 470034                 52
# 470035                 55
# 470036                 38
# 470037                 67
#
# [470038 rows x 23 columns]

# %% [markdown]
# Getting rid of null values in genres

# %%
df = df.dropna(subset=['genres'])

# %%
df.isna().sum()
# Out:
# track_id             0
# track_name           0
# track_popularity     0
# duration_ms          0
# explicit             0
# release_date         0
# danceability         0
# energy               0
# key                  0
# loudness             0
# mode                 0
# speechiness          0
# acousticness         0
# instrumentalness     0
# liveness             0
# valence              0
# tempo                0
# time_signature       0
# artist_id            0
# followers            0
# genres               0
# artist_name          0
# artist_popularity    0
# dtype: int64

# %% [markdown]
# I am going to create a variable with all of the numeric columns to scale and have them easily accessible when I plug them into functions.

# %%
num_cols = ['danceability', 'energy', 'loudness', 'key', 'mode',
       'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo', 'time_signature', 'track_popularity']

# %%
df['track_id']
# Out:
# 56        07A5yehtSnoedViJAZkNnc
# 57        08FmqUhxtyLTn6pAh6bk45
# 58        0JV4iqw2lSKJaHBQZ0e5zK
# 59        0l3BQsVJ7F76wlN5QhJzaP
# 60        0xJCJ9XSNcdTIz0QKmhtEn
#                    ...
# 470033    0MmaEacabpK8Yp3Mdeo5uY
# 470034    1dKxf4Ht2SsKLyXfSDJAgy
# 470035    0SjsIzJkZfDU7wlcdklEFR
# 470036    5rgu12WBIHQtvej2MdHSH0
# 470037    0NuWgxEp51CutD2pJoF4OM
# Name: track_id, Length: 432228, dtype: object

# %% [markdown]
# Scaling my numeric data so that it will run smoothly through the cosine similarity algorithm.

# %%
scaler = StandardScaler()

scaler.fit(df[num_cols])
# Out:
# StandardScaler()

# %%
scaled_data = pd.DataFrame(scaler.fit_transform(df[num_cols]), columns=num_cols)

# %%
scaled_data
# Out:
#         danceability    energy  loudness       key      mode  speechiness  \
# 0          -0.823764 -1.595823 -2.533133 -1.203130  0.712639    -0.265077
# 1          -1.534985 -1.936469 -4.034035  0.501498  0.712639    -0.269892
# 2          -0.106249 -2.165909 -2.986436  0.217393  0.712639     0.347572
# 3          -1.226580 -0.789683 -1.638480 -0.919025  0.712639    -0.052636
# 4          -1.421693 -1.931508 -3.808933  0.785602  0.712639    -0.254245
# ...              ...       ...       ...       ...       ...          ...
# 432223     -0.232129  0.454667  1.349378 -0.350816  0.712639    -0.384237
# 432224      0.277684 -2.256445 -4.169494  0.785602  0.712639     0.136936
# 432225     -0.018133 -2.190713 -3.500607 -1.203130  0.712639     0.046664
# 432226     -0.030721 -0.186111  0.501206 -1.487234 -1.403235    -0.397477
# 432227      1.259547  0.413326  0.998777 -1.487234  0.712639    -0.180823
#
#         acousticness  instrumentalness  liveness   valence     tempo  \
# 0           1.719770         -0.279239 -0.010532 -0.419442  0.367961
# 1           1.722753          3.581239 -0.590591 -0.656883  1.703360
# 2           1.725736          3.645853 -0.354271  0.193948 -1.482568
# 3           1.692923         -0.370211  3.840421  0.751936  1.355317
# 4           1.719770          3.800927 -0.488544 -1.361293 -1.121934
# ...              ...               ...       ...       ...       ...
# 432223     -0.818768         -0.373145 -0.617983 -1.052619  0.356079
# 432224      1.725736          3.818157 -0.569108  1.294093 -1.718040
# 432225      1.725736          3.766466 -0.552995 -0.700414 -1.884214
# 432226      1.096322         -0.373145 -0.801132 -1.392951  0.417850
# 432227     -0.824734         -0.371865 -0.652894  0.486793  1.032015
#
#         time_signature  track_popularity
# 0             2.512874         -1.733620
# 1            -1.992675         -1.733620
# 2            -1.992675         -1.733620
# 3             0.260100         -1.733620
# 4            -1.992675         -1.733620
# ...                ...               ...
# 432223        0.260100          1.190996
# 432224        0.260100          2.185366
# 432225       -1.992675          2.126874
# 432226        0.260100          1.190996
# 432227        0.260100          2.477828
#
# [432228 rows x 13 columns]

# %% [markdown]
# Making a new data frame to have track_id, track_name, and artist_name to plug into the algorithm.

# %%
df_track_info = df[['track_id', 'track_name', 'artist_name']]
df_track_info
# Out:
#                       track_id                          track_name  \
# 56      07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 57      08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 58      0JV4iqw2lSKJaHBQZ0e5zK       Martín Fierro - Remasterizado
# 59      0l3BQsVJ7F76wlN5QhJzaP         El Vendaval - Remasterizado
# 60      0xJCJ9XSNcdTIz0QKmhtEn           La Maleva - Remasterizado
# ...                        ...                                 ...
# 470033  0MmaEacabpK8Yp3Mdeo5uY                                 下雨天
# 470034  1dKxf4Ht2SsKLyXfSDJAgy                    The Cutest Puppy
# 470035  0SjsIzJkZfDU7wlcdklEFR                   John Brown's Song
# 470036  5rgu12WBIHQtvej2MdHSH0                                 云与海
# 470037  0NuWgxEp51CutD2pJoF4OM                               blind
#
#             artist_name
# 56      Ignacio Corsini
# 57      Ignacio Corsini
# 58      Ignacio Corsini
# 59      Ignacio Corsini
# 60      Ignacio Corsini
# ...                 ...
# 470033               芝麻
# 470034   Laureen Conrad
# 470035   Gregory Oberle
# 470036          阿YueYue
# 470037       ROLE MODEL
#
# [432228 rows x 3 columns]

# %%
df_track_info.head()
# Out:
#                   track_id                          track_name  \
# 56  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 57  08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 58  0JV4iqw2lSKJaHBQZ0e5zK       Martín Fierro - Remasterizado
# 59  0l3BQsVJ7F76wlN5QhJzaP         El Vendaval - Remasterizado
# 60  0xJCJ9XSNcdTIz0QKmhtEn           La Maleva - Remasterizado
#
#         artist_name
# 56  Ignacio Corsini
# 57  Ignacio Corsini
# 58  Ignacio Corsini
# 59  Ignacio Corsini
# 60  Ignacio Corsini

# %%
#df_track_info.join(scaled_data).isna().sum()
# Out:
# track_id                0
# track_name              0
# artist_name             0
# danceability        30810
# energy              30810
# loudness            30810
# key                 30810
# mode                30810
# speechiness         30810
# acousticness        30810
# instrumentalness    30810
# liveness            30810
# valence             30810
# tempo               30810
# time_signature      30810
# track_popularity    30810
# dtype: int64

# %% [markdown]
# The following code is from
# https://stackoverflow.com/questions/36538780/merging-dataframes-on-index-with-pandas

# %% [markdown]
# New dataframe with the scaled data and information on the track_id, track_name, and artist_name.
# - data is organized and ready to go through cosine similarity

# %%
df_mark = df_track_info.join(scaled_data, how='inner')
df_mark
# Out:
#                       track_id                          track_name  \
# 56      07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 57      08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 58      0JV4iqw2lSKJaHBQZ0e5zK       Martín Fierro - Remasterizado
# 59      0l3BQsVJ7F76wlN5QhJzaP         El Vendaval - Remasterizado
# 60      0xJCJ9XSNcdTIz0QKmhtEn           La Maleva - Remasterizado
# ...                        ...                                 ...
# 432223  65o7zOY79D5vqOJJNm1l3T                               下雨的晚上
# 432224  7D9yBn5ivJUao1v4jmVdgG                                 25歲
# 432225  6di4lDxW9XThds6gIHVRtL                               跟你出去玩
# 432226  4EoOSTT7iBjHxSfOfmB8Iq                                香格里拉
# 432227  7KJQsuGFRclzFzwtGXy1OC                                   你
#
#             artist_name  danceability    energy  loudness       key      mode  \
# 56      Ignacio Corsini     -1.446869 -1.930681 -3.926021  1.637916 -1.403235
# 57      Ignacio Corsini     -1.062936 -1.310573 -2.526493  0.217393  0.712639
# 58      Ignacio Corsini     -1.723805 -1.695040 -2.734995 -0.066712  0.712639
# 59      Ignacio Corsini     -0.792294 -1.674370 -2.487980  0.217393 -1.403235
# 60      Ignacio Corsini     -1.465751 -1.178284 -2.248712  0.785602  0.712639
# ...                 ...           ...       ...       ...       ...       ...
# 432223     Dadado Huang     -0.232129  0.454667  1.349378 -0.350816  0.712639
# 432224     Dadado Huang      0.277684 -2.256445 -4.169494  0.785602  0.712639
# 432225     Dadado Huang     -0.018133 -2.190713 -3.500607 -1.203130  0.712639
# 432226     Dadado Huang     -0.030721 -0.186111  0.501206 -1.487234 -1.403235
# 432227     Dadado Huang      1.259547  0.413326  0.998777 -1.487234  0.712639
#
#         speechiness  acousticness  instrumentalness  liveness   valence  \
# 56        -0.041803      1.725736          2.926482 -0.300562  0.379944
# 57        -0.233181      1.707838          3.473548 -0.262965  0.415560
# 58        -0.220543      1.722753         -0.292162 -0.144805  0.003995
# 59        -0.132678      1.704855          3.340013 -0.563737  0.724234
# 60        -0.123049      1.698889          3.775081 -0.198514 -0.063280
# ...             ...           ...               ...       ...       ...
# 432223    -0.384237     -0.818768         -0.373145 -0.617983 -1.052619
# 432224     0.136936      1.725736          3.818157 -0.569108  1.294093
# 432225     0.046664      1.725736          3.766466 -0.552995 -0.700414
# 432226    -0.397477      1.096322         -0.373145 -0.801132 -1.392951
# 432227    -0.180823     -0.824734         -0.371865 -0.652894  0.486793
#
#            tempo  time_signature  track_popularity
# 56      0.933857        2.512874         -1.733620
# 57     -1.879927        0.260100         -1.733620
# 58      1.945178        0.260100         -1.733620
# 59      1.656644        0.260100         -1.733620
# 60      2.026054       -1.992675         -1.733620
# ...          ...             ...               ...
# 432223  0.356079        0.260100          1.190996
# 432224 -1.718040        0.260100          2.185366
# 432225 -1.884214       -1.992675          2.126874
# 432226  0.417850        0.260100          1.190996
# 432227  1.032015        0.260100          2.477828
#
# [401418 rows x 16 columns]

# %%
# refers to the columns to the right of artist name (all num cols)
df_mark.iloc[:,3:]
# Out:
#         danceability    energy  loudness       key      mode  speechiness  \
# 56         -1.446869 -1.930681 -3.926021  1.637916 -1.403235    -0.041803
# 57         -1.062936 -1.310573 -2.526493  0.217393  0.712639    -0.233181
# 58         -1.723805 -1.695040 -2.734995 -0.066712  0.712639    -0.220543
# 59         -0.792294 -1.674370 -2.487980  0.217393 -1.403235    -0.132678
# 60         -1.465751 -1.178284 -2.248712  0.785602  0.712639    -0.123049
# ...              ...       ...       ...       ...       ...          ...
# 432223     -0.232129  0.454667  1.349378 -0.350816  0.712639    -0.384237
# 432224      0.277684 -2.256445 -4.169494  0.785602  0.712639     0.136936
# 432225     -0.018133 -2.190713 -3.500607 -1.203130  0.712639     0.046664
# 432226     -0.030721 -0.186111  0.501206 -1.487234 -1.403235    -0.397477
# 432227      1.259547  0.413326  0.998777 -1.487234  0.712639    -0.180823
#
#         acousticness  instrumentalness  liveness   valence     tempo  \
# 56          1.725736          2.926482 -0.300562  0.379944  0.933857
# 57          1.707838          3.473548 -0.262965  0.415560 -1.879927
# 58          1.722753         -0.292162 -0.144805  0.003995  1.945178
# 59          1.704855          3.340013 -0.563737  0.724234  1.656644
# 60          1.698889          3.775081 -0.198514 -0.063280  2.026054
# ...              ...               ...       ...       ...       ...
# 432223     -0.818768         -0.373145 -0.617983 -1.052619  0.356079
# 432224      1.725736          3.818157 -0.569108  1.294093 -1.718040
# 432225      1.725736          3.766466 -0.552995 -0.700414 -1.884214
# 432226      1.096322         -0.373145 -0.801132 -1.392951  0.417850
# 432227     -0.824734         -0.371865 -0.652894  0.486793  1.032015
#
#         time_signature  track_popularity
# 56            2.512874         -1.733620
# 57            0.260100         -1.733620
# 58            0.260100         -1.733620
# 59            0.260100         -1.733620
# 60           -1.992675         -1.733620
# ...                ...               ...
# 432223        0.260100          1.190996
# 432224        0.260100          2.185366
# 432225       -1.992675          2.126874
# 432226        0.260100          1.190996
# 432227        0.260100          2.477828
#
# [401418 rows x 13 columns]

# %%
# looks at just the first three track data columns
df_mark.iloc[:,:3]
# Out:
#                       track_id                          track_name  \
# 56      07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
# 57      08FmqUhxtyLTn6pAh6bk45       El Prisionero - Remasterizado
# 58      0JV4iqw2lSKJaHBQZ0e5zK       Martín Fierro - Remasterizado
# 59      0l3BQsVJ7F76wlN5QhJzaP         El Vendaval - Remasterizado
# 60      0xJCJ9XSNcdTIz0QKmhtEn           La Maleva - Remasterizado
# ...                        ...                                 ...
# 432223  65o7zOY79D5vqOJJNm1l3T                               下雨的晚上
# 432224  7D9yBn5ivJUao1v4jmVdgG                                 25歲
# 432225  6di4lDxW9XThds6gIHVRtL                               跟你出去玩
# 432226  4EoOSTT7iBjHxSfOfmB8Iq                                香格里拉
# 432227  7KJQsuGFRclzFzwtGXy1OC                                   你
#
#             artist_name
# 56      Ignacio Corsini
# 57      Ignacio Corsini
# 58      Ignacio Corsini
# 59      Ignacio Corsini
# 60      Ignacio Corsini
# ...                 ...
# 432223     Dadado Huang
# 432224     Dadado Huang
# 432225     Dadado Huang
# 432226     Dadado Huang
# 432227     Dadado Huang
#
# [401418 rows x 3 columns]

# %%
# From a track_name to a track_id (Track must exactly match)
track = 'House of the Rising Sun'
df_mark[df_mark['track_name'] == track][['artist_name', 'track_id']]
# Out:
#                     artist_name                track_id
# 39924               Pete Seeger  2bT8S1aNa6nAcMrDVfw3Xr
# 74229               The Animals  4mn2kNTqiGLwaUR8JdhJ1l
# 74234               The Animals  3XC7Jd6SfrQYKZJ6inyRHK
# 74238               The Animals  1D8MLfoyeJr3W7sEYsDoyv
# 74306               The Animals  0ev91hkSfD8mR15VBiAHts
# 119396           Idris Muhammad  0ggo2PQvf6xG7RWF5z1pHN
# 261078  Five Finger Death Punch  2SgQsZIWs0UC01ibNOBu7q
# 397123                  Gildran  0jIDNggEsTbXOr8h8WBtTa

# %%
def find_track_id(track):
    return df_mark[df_mark['track_name'] == track][['artist_name', 'track_id']]

# %%
find_track_id("House of the Rising Sun")
# Out:
#                     artist_name                track_id
# 39924               Pete Seeger  2bT8S1aNa6nAcMrDVfw3Xr
# 74229               The Animals  4mn2kNTqiGLwaUR8JdhJ1l
# 74234               The Animals  3XC7Jd6SfrQYKZJ6inyRHK
# 74238               The Animals  1D8MLfoyeJr3W7sEYsDoyv
# 74306               The Animals  0ev91hkSfD8mR15VBiAHts
# 119396           Idris Muhammad  0ggo2PQvf6xG7RWF5z1pHN
# 261078  Five Finger Death Punch  2SgQsZIWs0UC01ibNOBu7q
# 397123                  Gildran  0jIDNggEsTbXOr8h8WBtTa

# %%
trackID = '2bT8S1aNa6nAcMrDVfw3Xr'

def cosSim(trackID):
    '''
    Takes in a trackID,
    returns top 10 most similar tracks
    '''
    track_num_cols = df_mark[df_mark['track_id'] == trackID].iloc[:,3:]
    cos_sim = cosine_similarity
    return 
    
    #return track_name

# %%
cosSim(trackID).values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-255afe6487e0> in <module>
# ----> 1 cosSim(trackID).values
#
# AttributeError: 'NoneType' object has no attribute 'values'

# %%
df_mark.loc[df_mark['track_id'] == '2bT8S1aNa6nAcMrDVfw3Xr']
# Out:
#                      track_id               track_name  artist_name  \
# 39924  2bT8S1aNa6nAcMrDVfw3Xr  House of the Rising Sun  Pete Seeger
#
#        danceability    energy  loudness       key      mode  speechiness  \
# 39924      0.982611 -1.033592  -0.88814 -0.919025 -1.403235    -0.182629
#
#        acousticness  instrumentalness  liveness   valence   tempo  \
# 39924      1.182829         -0.373138 -0.268336  0.601556  0.1361
#
#        time_signature  track_popularity
# 39924          0.2601          0.196627

# %%
song_0 = df[num_cols][df['track_id'] == '2bT8S1aNa6nAcMrDVfw3Xr']
song_1 = df_mark.iloc[:,3:][df_mark['track_id'] == '1gqkRc9WtOpnGIqxf2Hvzr']

# %%
song_1
# Out:
#         danceability    energy  loudness       key      mode  speechiness  \
# 249853     -0.584592 -0.607785  0.266808 -0.919025  0.712639    -0.391459
#
#         acousticness  instrumentalness  liveness   valence     tempo  \
# 249853      1.275302         -0.373145 -0.714123 -0.922026 -0.349291
#
#         time_signature  track_popularity
# 249853          0.2601          1.190996

# %%
track_num_cols = df_mark[df_mark['track_id'] == trackID].iloc[:,3:]

# %%
for index, row in df_mark.iloc[:,3:][:5].iterrows():
    print(row)#cosine_similarity(track_num_cols, row)
    
# [row for index, row in df_mark.iterrows()]
# Out:
#   File "<ipython-input-52-2a7ab5edb01b>", line 2
#     print(row)cosine_similarity(track_num_cols, row)
#               ^
# SyntaxError: invalid syntax

# %%
song_1
# Out:
#         danceability    energy  loudness       key      mode  speechiness  \
# 249853     -0.584592 -0.607785  0.266808 -0.919025  0.712639    -0.391459
#
#         acousticness  instrumentalness  liveness   valence     tempo  \
# 249853      1.275302         -0.373145 -0.714123 -0.922026 -0.349291
#
#         time_signature  track_popularity
# 249853          0.2601          1.190996

# %%
cos_sim = cosine_similarity(song_0, song_1)
cos_sim
# Out:
# array([[0.38190865]])

# %%
num_cols
# Out:
# ['danceability',
#  'energy',
#  'loudness',
#  'key',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'time_signature',
#  'track_popularity']

# %%
song_0_sc = scaler.transform(song_0)

# %%
df_mark.head()[num_cols]
# Out:
#     danceability    energy  loudness       key      mode  speechiness  \
# 56     -1.446869 -1.930681 -3.926021  1.637916 -1.403235    -0.041803
# 57     -1.062936 -1.310573 -2.526493  0.217393  0.712639    -0.233181
# 58     -1.723805 -1.695040 -2.734995 -0.066712  0.712639    -0.220543
# 59     -0.792294 -1.674370 -2.487980  0.217393 -1.403235    -0.132678
# 60     -1.465751 -1.178284 -2.248712  0.785602  0.712639    -0.123049
#
#     acousticness  instrumentalness  liveness   valence     tempo  \
# 56      1.725736          2.926482 -0.300562  0.379944  0.933857
# 57      1.707838          3.473548 -0.262965  0.415560 -1.879927
# 58      1.722753         -0.292162 -0.144805  0.003995  1.945178
# 59      1.704855          3.340013 -0.563737  0.724234  1.656644
# 60      1.698889          3.775081 -0.198514 -0.063280  2.026054
#
#     time_signature  track_popularity
# 56        2.512874          -1.73362
# 57        0.260100          -1.73362
# 58        0.260100          -1.73362
# 59        0.260100          -1.73362
# 60       -1.992675          -1.73362

# %%
df_mark['artist_name'].unique()
# Out:
# array(['Ignacio Corsini', 'Dick Haymes', 'Mistinguett', ...,
#        'Green River Ordinance', 'Koala Liu', 'Dadado Huang'], dtype=object)

# %%
song_0_sc
# Out:
# array([[-0.55312249, -2.10555171, -3.20866072,  1.35381121,  0.71263911,
#         -0.33669367,  1.62133114, -0.33933007, -0.76729484,  0.06731304,
#         -0.086714  , -1.99267451, -1.32417391]])

# %%
df_mark[num_cols].iloc[0].values.reshape(1, -1)
# Out:
# array([[-1.44686919, -1.9306813 , -3.92602115,  1.63791577, -1.4032348 ,
#         -0.04180339,  1.72573637,  2.9264823 , -0.30056155,  0.37994417,
#          0.93385655,  2.51287429, -1.73362026]])

# %%
df_mark.head(10)[num_cols]
# Out:
#     danceability    energy  loudness       key      mode  speechiness  \
# 56     -1.446869 -1.930681 -3.926021  1.637916 -1.403235    -0.041803
# 57     -1.062936 -1.310573 -2.526493  0.217393  0.712639    -0.233181
# 58     -1.723805 -1.695040 -2.734995 -0.066712  0.712639    -0.220543
# 59     -0.792294 -1.674370 -2.487980  0.217393 -1.403235    -0.132678
# 60     -1.465751 -1.178284 -2.248712  0.785602  0.712639    -0.123049
# 61     -0.987408 -1.509008 -2.976919 -0.350816  0.712639    -0.241005
# 62     -0.037015 -1.757051 -2.775279 -0.919025  0.712639     0.130918
# 63     -3.555356 -2.220892 -3.355187 -0.066712  0.712639    -0.573208
# 64     -0.767118 -2.096870 -2.785460 -0.634921  0.712639     0.142954
# 65     -0.446125 -1.868671 -2.988871 -0.066712  0.712639    -0.180221
#
#     acousticness  instrumentalness  liveness   valence     tempo  \
# 56      1.725736          2.926482 -0.300562  0.379944  0.933857
# 57      1.707838          3.473548 -0.262965  0.415560 -1.879927
# 58      1.722753         -0.292162 -0.144805  0.003995  1.945178
# 59      1.704855          3.340013 -0.563737  0.724234  1.656644
# 60      1.698889          3.775081 -0.198514 -0.063280  2.026054
# 61      1.678008          3.503702 -0.536882 -1.634350  0.043545
# 62      1.722753          3.533855  0.129112 -0.273020 -0.276617
# 63      1.725736          2.935098 -0.702844 -2.227953 -4.034248
# 64      1.719770          3.628622  0.531932  0.063356 -1.522365
# 65      1.722753          2.573259 -0.203885  0.281010  0.276688
#
#     time_signature  track_popularity
# 56        2.512874         -1.733620
# 57        0.260100         -1.733620
# 58        0.260100         -1.733620
# 59        0.260100         -1.733620
# 60       -1.992675         -1.733620
# 61        0.260100         -1.733620
# 62        0.260100         -1.733620
# 63       -8.750998         -1.675128
# 64        0.260100         -1.733620
# 65        0.260100         -1.733620

# %%
df_mark.shape
# Out:
# (401418, 16)

# %%
test = df_mark.groupby('artist_name').first().reset_index()

# %%
test_series = test[num_cols].apply(lambda x: cosine_similarity(song_0_sc, x.values.reshape(1, -1)), axis=1)

# %%
test_series.str[0].str[0].sort_values().tail(10)
# Out:
# 15374    0.905102
# 17547    0.906397
# 20864    0.909415
# 29647    0.913536
# 26880    0.921018
# 28406    0.921995
# 15229    0.927315
# 14110    0.931193
# 22585    0.932682
# 9996     0.957633
# dtype: float64

# %%
similarity = {}
for t_id in df_mark['track_id']:
    song_1 = df_mark[num_cols][df_mark['track_id'] == t_id]
    sim = cosine_similarity(song_0_sc, song_1)[0][0]
    similarity[t_id] = sim
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-57de442c5f8c> in <module>
#       1 similarity = {}
#       2 for t_id in df_mark['track_id']:
# ----> 3     song_1 = df_mark[num_cols][df_mark['track_id'] == t_id]
#       4     sim = cosine_similarity(song_0_sc, song_1)[0][0]
#       5     similarity[t_id] = sim
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2912             indexer = np.where(indexer)[0]
#    2913
# -> 2914         data = self._take_with_is_copy(indexer, axis=1)
#    2915
#    2916         if is_single_key:
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3361         See the docstring of `take` for full explanation of the parameters.
#    3362         """
# -> 3363         result = self.take(indices=indices, axis=axis)
#    3364         # Maybe set copy if we didn't actually change the index.
#    3365         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3348         self._consolidate_inplace()
#    3349
# -> 3350         new_data = self._mgr.take(
#    3351             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3352         )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify, convert)
#    1445
#    1446         new_labels = self.axes[axis].take(indexer)
# -> 1447         return self.reindex_indexer(
#    1448             new_axis=new_labels, indexer=indexer, axis=axis, allow_dups=True
#    1449         )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate)
#    1280
#    1281         if axis == 0:
# -> 1282             new_blocks = self._slice_take_blocks_ax0(indexer, fill_value=fill_value)
#    1283         else:
#    1284             new_blocks = [
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/managers.py in _slice_take_blocks_ax0(self, slice_or_indexer, fill_value, only_slice)
#    1408                             blocks.append(nb)
#    1409                     else:
# -> 1410                         nb = blk.take_nd(taker, axis=0, new_mgr_locs=mgr_locs)
#    1411                         blocks.append(nb)
#    1412
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/internals/blocks.py in take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1253             allow_fill = True
#    1254
# -> 1255         new_values = algos.take_nd(
#    1256             values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1257         )
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/algorithms.py in take_nd(arr, indexer, axis, out, fill_value, allow_fill)
#    1711         arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#    1712     )
# -> 1713     func(arr, indexer, out, fill_value)
#    1714
#    1715     if flip_order:
#
# KeyboardInterrupt:

# %%
sorted_dict = {k:v for k,v in sorted(similarity.items(), key=lambda k: k[1], reverse=True)}
top_10 = list(sorted_dict.keys())[:10]

# %%
for track_id in top_10:
    track = df_mark.loc[df_mark['track_id'] == track_id]
    display(track[['artist_name', 'track_name']])
# Out:
#           artist_name                      track_name
# 9885  Carroll Gibbons  Dream Mother (Carroll Gibbons)
#             artist_name    track_name
# 15512  Django Reinhardt  Twelfth Year
#            artist_name                               track_name
# 2885  Francisco Canaro  Burrerro - Instrumental (Remasterizado)
#          artist_name       track_name
# 17554  Andy Williams  Try to Remember
#         artist_name                                track_name
# 15380  Glenn Miller  Moonlight Serenade / Running Wild - Live
#                artist_name    track_name
# 10529  Stratos Pagioumtzis  Sampah Manes
#            artist_name                                        track_name
# 2872  Francisco Canaro  Primavera de Amor - Instrumental (Remasterizado)
#          artist_name                                         track_name
# 17547  Andy Williams  The Christmas Song (Chestnuts Roasting On an O...
#          artist_name                                         track_name
# 4518  Billie Holiday  Reading From "Lady Sings The Blues" 5 - Live A...
#          artist_name                 track_name
# 249  Ignacio Corsini  La Espera - Remasterizado

# %%
list(similarity.values())[0]
# Out:
# 0.5038497689969865

# %%
df_mark.loc[df_mark['track_id'] == list(similarity.keys())[0]]
# Out:
#                   track_id                          track_name  \
# 56  07A5yehtSnoedViJAZkNnc  Vivo para Quererte - Remasterizado
#
#         artist_name  danceability    energy  loudness       key      mode  \
# 56  Ignacio Corsini     -1.446869 -1.930681 -3.926021  1.637916 -1.403235
#
#     speechiness  acousticness  instrumentalness  liveness   valence     tempo  \
# 56    -0.041803      1.725736          2.926482 -0.300562  0.379944  0.933857
#
#     time_signature  track_popularity
# 56        2.512874          -1.73362
